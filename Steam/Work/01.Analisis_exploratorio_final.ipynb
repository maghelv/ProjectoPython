# %% [markdown]
# # Definicion del Problema

# %% [markdown]
# El problema identificado es la optimización de las estrategias de ventas de videojuegos en la plataforma Steam.
#
# En particular, se busca comprender las tendencias de ventas, los patrones estacionales y el impacto de las ofertas y descuentos en las ventas. Esto permitirá ajustar las estrategias de precios para maximizar los ingresos y mejorar la competitividad en el mercado de videojuegos.

# %% [markdown]
# ## Preguntas a Resolver

# %% [markdown]
# 1-.¿Cuáles son las tendencias generales de ventas de videojuegos en Steam durante el último año?
#
# R:Esta pregunta busca identificar patrones de crecimiento o declive en las ventas generales de la plataforma.
#
# 2.-¿Cómo varían las ventas de videojuegos en Steam según las diferentes estaciones del año?
#
# R:Conocer los patrones estacionales puede ayudar a identificar los momentos más y menos activos para las ventas.
#
# 3-.¿Qué impacto tienen las ofertas y descuentos en las ventas de videojuegos en Steam?
#
# R:Analizar la efectividad de las promociones y descuentos en el incremento de ventas durante y después de su vigencia.
#
# 4-.¿Cuáles características de los videojuegos (como el género, el desarrollador, las calificaciones de usuarios, etc.) están más asociadas con mayores ventas en Steam?
#
# R:Identificar factores internos de los juegos que podrían estar influyendo en su éxito de ventas.
#
# 5-.¿Cómo afectan las revisiones y calificaciones de los usuarios a las ventas de videojuegos en Steam?
#
# R:Evaluar la influencia de las opiniones y calificaciones de los usuarios en la percepción y decisión de compra de potenciales compradores.
#
# 6-.¿Cuál es el tiempo promedio que un videojuego se mantiene en los rankings de más vendidos en Steam y qué factores influyen en su duración?
#
# R:Determinar la longevidad de un juego en los rankings de más vendidos y los factores que contribuyen a ello.
#
# 7-.¿Qué patrones de compra se observan durante eventos de venta masivos como Steam Summer Sale o Steam Winter Sale?
#
# R:Analizar los comportamientos de compra durante eventos específicos de gran relevancia.
#
# 8-.¿Cómo varían las ventas de videojuegos en Steam según las diferentes regiones geográficas?
#
# R:Entender las diferencias de ventas por región puede ayudar a diseñar estrategias de mercado más focalizadas.

# %% [markdown]
# ## Importartando la base de datos

# %% [markdown]
# Durante este trabajo haremos un analisis exploratorio y limpieza de nuestro data set, a lo largo de notebook veremos varios
# metodos para limpiar nuestro dataset.

# %%
import pandas as pd

# %% [markdown]
# Ahora abrimos nuestro dataset con " .read_csv('') "

# %%
df = pd.read_csv('../Datasets/steam.csv')
df
# Out:
#                                                 title  \
# 0                       Ori and the Will of the Wisps
# 1   Flashing Lights - Police, Firefighting, Emerge...
# 2                                          Thronefall
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                             UNDYING
# ..                                                ...
# 81                         Bendy and the Dark Revival
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...
# 83                                           Thymesia
# 84                                    Last Train Home
# 85                                         Fallout 76
#
#                                           description   price salePercentage  \
# 0   Play the critically acclaimed masterpiece. Emb...   $9.89           -67%
# 1   Play solo or in up to 10-player multiplayer co...   $8.49           -66%
# 2   A minimalist game about building and defending...   $5.24           -25%
# 3   The Definitive Edition includes the critically...  $23.99           -40%
# 4   As Anling’s zombie infection sets in, her days...  $13.99           -30%
# ..                                                ...     ...            ...
# 81  Bendy and the Dark Revival® is a first-person ...   $5.99           -80%
# 82  A game that will show gamers the deepest, dark...   $6.99           -65%
# 83  Thymesia is a gruelling action-RPG with fast-p...  $14.99           -40%
# 84  The Great War is over - the fight continues. C...  $26.39           -34%
# 85  Bethesda Game Studios welcome you to Fallout 7...   $9.99           -75%
#
#               recentReviews               allReviews
# 0   Overwhelmingly Positive  Overwhelmingly Positive
# 1             Very Positive            Very Positive
# 2   Overwhelmingly Positive  Overwhelmingly Positive
# 3             Very Positive            Very Positive
# 4           Mostly Positive          Mostly Positive
# ..                      ...                      ...
# 81            Very Positive            Very Positive
# 82            Very Positive            Very Positive
# 83            Very Positive            Very Positive
# 84            Very Positive            Very Positive
# 85          Mostly Positive          Mostly Positive
#
# [86 rows x 6 columns]

# %% [markdown]
# ## Mostrando los primeros 5

# %% [markdown]
# En este apartado mostraremos los 5 primeros datos de nuestro dataset

# %%
df = pd.read_csv('../Datasets/steam.csv')
df.head(5)
# Out:
#                                                title  \
# 0                      Ori and the Will of the Wisps
# 1  Flashing Lights - Police, Firefighting, Emerge...
# 2                                         Thronefall
# 3  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                            UNDYING
#
#                                          description   price salePercentage  \
# 0  Play the critically acclaimed masterpiece. Emb...   $9.89           -67%
# 1  Play solo or in up to 10-player multiplayer co...   $8.49           -66%
# 2  A minimalist game about building and defending...   $5.24           -25%
# 3  The Definitive Edition includes the critically...  $23.99           -40%
# 4  As Anling’s zombie infection sets in, her days...  $13.99           -30%
#
#              recentReviews               allReviews
# 0  Overwhelmingly Positive  Overwhelmingly Positive
# 1            Very Positive            Very Positive
# 2  Overwhelmingly Positive  Overwhelmingly Positive
# 3            Very Positive            Very Positive
# 4          Mostly Positive          Mostly Positive

# %% [markdown]
# ## Mostrando los ultimos 5

# %% [markdown]
# En este apartado mostraremos los ultimos 5 datos de nuestro dataset

# %%
df.tail(5)
# Out:
#                                                 title  \
# 81                         Bendy and the Dark Revival
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...
# 83                                           Thymesia
# 84                                    Last Train Home
# 85                                         Fallout 76
#
#                                           description   price salePercentage  \
# 81  Bendy and the Dark Revival® is a first-person ...   $5.99           -80%
# 82  A game that will show gamers the deepest, dark...   $6.99           -65%
# 83  Thymesia is a gruelling action-RPG with fast-p...  $14.99           -40%
# 84  The Great War is over - the fight continues. C...  $26.39           -34%
# 85  Bethesda Game Studios welcome you to Fallout 7...   $9.99           -75%
#
#       recentReviews       allReviews
# 81    Very Positive    Very Positive
# 82    Very Positive    Very Positive
# 83    Very Positive    Very Positive
# 84    Very Positive    Very Positive
# 85  Mostly Positive  Mostly Positive

# %% [markdown]
# ## Tipos de Datos

# %% [markdown]
# A continuacion con dtypes, podremos ver el tipo de datos que estan almacenados en el dataset

# %%
df.dtypes
# Out:
# title             object
# description       object
# price             object
# salePercentage    object
# recentReviews     object
# allReviews        object
# dtype: object

# %% [markdown]
# ## Columnas y Informacion

# %% [markdown]
# En este apartado mostraremos las columnas que estan en el dataset

# %%
df.columns
# Out:
# Index(['title', 'description', 'price', 'salePercentage', 'recentReviews',
#        'allReviews'],
#       dtype='object')

# %% [markdown]
# ## Descripcion de los Datos

# %% [markdown]
# Usando el " describe " podremos ver la descripcion que tiene el dataset

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                 title  \
# 0                       Ori and the Will of the Wisps
# 1   Flashing Lights - Police, Firefighting, Emerge...
# 2                                          Thronefall
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                             UNDYING
# ..                                                ...
# 81                         Bendy and the Dark Revival
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...
# 83                                           Thymesia
# 84                                    Last Train Home
# 85                                         Fallout 76
#
#                                           description   price salePercentage  \
# 0   Play the critically acclaimed masterpiece. Emb...   $9.89           -67%
# 1   Play solo or in up to 10-player multiplayer co...   $8.49           -66%
# 2   A minimalist game about building and defending...   $5.24           -25%
# 3   The Definitive Edition includes the critically...  $23.99           -40%
# 4   As Anling’s zombie infection sets in, her days...  $13.99           -30%
# ..                                                ...     ...            ...
# 81  Bendy and the Dark Revival® is a first-person ...   $5.99           -80%
# 82  A game that will show gamers the deepest, dark...   $6.99           -65%
# 83  Thymesia is a gruelling action-RPG with fast-p...  $14.99           -40%
# 84  The Great War is over - the fight continues. C...  $26.39           -34%
# 85  Bethesda Game Studios welcome you to Fallout 7...   $9.99           -75%
#
#               recentReviews               allReviews
# 0   Overwhelmingly Positive  Overwhelmingly Positive
# 1             Very Positive            Very Positive
# 2   Overwhelmingly Positive  Overwhelmingly Positive
# 3             Very Positive            Very Positive
# 4           Mostly Positive          Mostly Positive
# ..                      ...                      ...
# 81            Very Positive            Very Positive
# 82            Very Positive            Very Positive
# 83            Very Positive            Very Positive
# 84            Very Positive            Very Positive
# 85          Mostly Positive          Mostly Positive
#
# [86 rows x 6 columns]>

# %% [markdown]
# ## Informacion del Dataset

# %% [markdown]
# En este apartado con el .info podremos ver la informacion del dataset

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 title  \
# 0                       Ori and the Will of the Wisps
# 1   Flashing Lights - Police, Firefighting, Emerge...
# 2                                          Thronefall
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                             UNDYING
# ..                                                ...
# 81                         Bendy and the Dark Revival
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...
# 83                                           Thymesia
# 84                                    Last Train Home
# 85                                         Fallout 76
#
#                                           description   price salePercentage  \
# 0   Play the critically acclaimed masterpiece. Emb...   $9.89           -67%
# 1   Play solo or in up to 10-player multiplayer co...   $8.49           -66%
# 2   A minimalist game about building and defending...   $5.24           -25%
# 3   The Definitive Edition includes the critically...  $23.99           -40%
# 4   As Anling’s zombie infection sets in, her days...  $13.99           -30%
# ..                                                ...     ...            ...
# 81  Bendy and the Dark Revival® is a first-person ...   $5.99           -80%
# 82  A game that will show gamers the deepest, dark...   $6.99           -65%
# 83  Thymesia is a gruelling action-RPG with fast-p...  $14.99           -40%
# 84  The Great War is over - the fight continues. C...  $26.39           -34%
# 85  Bethesda Game Studios welcome you to Fallout 7...   $9.99           -75%
#
#               recentReviews               allReviews
# 0   Overwhelmingly Positive  Overwhelmingly Positive
# 1             Very Positive            Very Positive
# 2   Overwhelmingly Positive  Overwhelmingly Positive
# 3             Very Positive            Very Positive
# 4           Mostly Positive          Mostly Positive
# ..                      ...                      ...
# 81            Very Positive            Very Positive
# 82            Very Positive            Very Positive
# 83            Very Positive            Very Positive
# 84            Very Positive            Very Positive
# 85          Mostly Positive          Mostly Positive
#
# [86 rows x 6 columns]>

# %% [markdown]
# ## Tamaño de conjuntos

# %% [markdown]
# Con el .shape, veremos el tamaño de los conjuntos de los datos almacenados en el dataset

# %%
df.shape
# Out:
# (86, 6)

# %% [markdown]
# ## Visualizando los NaN que contiene el Dataset

# %% [markdown]
# Con .isna().sum() Podremos visualizar los nans que estan en el data set

# %%
import numpy as np
import pandas as pd

# %%
df.isna().sum()
# Out:
# title              0
# description        4
# price             25
# salePercentage    27
# recentReviews     29
# allReviews        29
# dtype: int64

# %% [markdown]
# ## Remplazar simbolos

# %% [markdown]
# En este apartado veremos el siguiente comando que sera capaz de remplazar cualquier simbolo en el dataset, en este caso para eliminarlo y o cambiarlo por otro.

# %%
df['price'] =df['price'].str.replace('$',' ').astype(float)

# %%
df.dtypes
# Out:
# title              object
# description        object
# price             float64
# salePercentage     object
# recentReviews      object
# allReviews         object
# dtype: object

# %% [markdown]
# ## Eliminar los NaNs

# %% [markdown]
# En este apartado veremos como eliminar los nans de nuestro dataset, a continuacion veremos la visualizacion para saber cuantos nans tenemos y tenemos que eliminar

# %%
df_limpio = df.copy()

# %%
df_limpio.isna().sum()
# Out:
# title              0
# description        4
# price             25
# salePercentage    27
# recentReviews     29
# allReviews        29
# dtype: int64

# %% [markdown]
# En este apartado eliminaremos los nans del dataset, usando un .dropna

# %%
df_nuevo = df_limpio.dropna(how='any', axis=0)

# %%
df_nuevo.isna().sum()
# Out:
# title             0
# description       0
# price             0
# salePercentage    0
# recentReviews     0
# allReviews        0
# dtype: int64

# %% [markdown]
# En este apartado se como el data set ya limpio de nans

# %%
df_nuevo
# Out:
#                                                 title  \
# 0                       Ori and the Will of the Wisps
# 1   Flashing Lights - Police, Firefighting, Emerge...
# 2                                          Thronefall
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                             UNDYING
# 5                          Headbangers: Rhythm Royale
# 6                          Bendy and the Dark Revival
# 7                                             CARRION
# 8                                            Thymesia
# 9                               Boxes: Lost Fragments
# 10                                           HELLCARD
# 11                                        Moonbreaker
# 12                            BlazBlue Entropy Effect
# 14                                       Ready or Not
# 15                FINAL FANTASY VII REMAKE INTERGRADE
# 16                                          Destiny 2
# 17                                    Hogwarts Legacy
# 18                                   Dead by Daylight
# 19                                     Hell Let Loose
# 23                                      Halo Infinite
# 49                                       Ready or Not
# 50                FINAL FANTASY VII REMAKE INTERGRADE
# 51                                         God of War
# 53                                    Hogwarts Legacy
# 54                     Marvel’s Spider-Man Remastered
# 55                 Marvel’s Spider-Man: Miles Morales
# 56                                          Days Gone
# 57                        Ratchet & Clank: Rift Apart
# 58                      Ori and the Will of the Wisps
# 59  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 60            CRISIS CORE –FINAL FANTASY VII– REUNION
# 61           UNCHARTED™: Legacy of Thieves Collection
# 62                                         Thronefall
# 63                                      Overcooked! 2
# 64                                         Dead Space
# 65                                            CARRION
# 66                   FINAL FANTASY XII THE ZODIAC AGE
# 67                                       Atomic Heart
# 69                                          Returnal™
# 70                    FINAL FANTASY X/X-2 HD Remaster
# 71        The Elder Scrolls V: Skyrim Special Edition
# 72               STAR WARS™ Empire at War - Gold Pack
# 73                   FINAL FANTASY XV WINDOWS EDITION
# 74                                   Dead by Daylight
# 75           Star Wars: Battlefront 2 (Classic, 2005)
# 77          STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 78                                           Grounded
# 79  Flashing Lights - Police, Firefighting, Emerge...
# 80               LEGO® Star Wars™ - The Complete Saga
# 81                         Bendy and the Dark Revival
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...
# 83                                           Thymesia
# 84                                    Last Train Home
# 85                                         Fallout 76
#
#                                           description  price salePercentage  \
# 0   Play the critically acclaimed masterpiece. Emb...   9.89           -67%
# 1   Play solo or in up to 10-player multiplayer co...   8.49           -66%
# 2   A minimalist game about building and defending...   5.24           -25%
# 3   The Definitive Edition includes the critically...  23.99           -40%
# 4   As Anling’s zombie infection sets in, her days...  13.99           -30%
# 5   Headbangers is a light-hearted, Rhythm Battle ...  13.39           -33%
# 6   Bendy and the Dark Revival® is a first-person ...   5.99           -80%
# 7   CARRION is a reverse horror game in which you ...   5.99           -70%
# 8   Thymesia is a gruelling action-RPG with fast-p...  14.99           -40%
# 9   As a legendary thief, your next assignment lur...  13.49           -10%
# 10  Hellcard is a unique cooperative deck builder ...  15.79           -21%
# 11  Moonbreaker is a turn-based strategy, tactical...  22.49           -25%
# 12  Artistic and Magnificent Combat Action, incred...  17.15           -22%
# 14  Ready or Not is an intense, tactical, first-pe...  37.49           -25%
# 15  Cloud Strife, an ex-SOLDIER operative, descend...  34.99           -50%
# 16  Destiny 2 is an action MMO with a single evolv...  14.99           -75%
# 17  Hogwarts Legacy is an immersive, open-world ac...  35.99           -40%
# 18  Dead by Daylight is a multiplayer (4vs1) horro...   7.99           -60%
# 19  Join the ever expanding experience of Hell Let...  42.24           -35%
# 23  From one of gaming's most iconic sagas, Halo i...  23.99           -60%
# 49  Ready or Not is an intense, tactical, first-pe...  37.49           -25%
# 50  Cloud Strife, an ex-SOLDIER operative, descend...  34.99           -50%
# 51  His vengeance against the Gods of Olympus year...  24.99           -50%
# 53  Hogwarts Legacy is an immersive, open-world ac...  35.99           -40%
# 54  In Marvel’s Spider-Man Remastered, the worlds ...  35.99           -40%
# 55  After the events of Marvel’s Spider-Man Remast...  29.99           -40%
# 56  Ride and fight into a deadly, post pandemic Am...  12.49           -75%
# 57  Blast your way through an interdimensional adv...  40.19           -33%
# 58  Play the critically acclaimed masterpiece. Emb...   9.89           -67%
# 59  The Definitive Edition includes the critically...  23.99           -40%
# 60  CRISIS CORE -FINAL FANTASY VII- REUNION is a r...  29.99           -40%
# 61  Play as Nathan Drake and Chloe Frazer in their...  24.99           -50%
# 62  A minimalist game about building and defending...   5.24           -25%
# 63  Overcooked returns with a brand-new helping of...   6.24           -75%
# 64  The sci-fi survival-horror classic returns, co...  23.99           -60%
# 65  CARRION is a reverse horror game in which you ...   5.99           -70%
# 66  FINAL FANTASY XII THE ZODIAC AGE - This revere...  19.99           -60%
# 67  In a mad and sublime utopian world, take part ...  29.99           -50%
# 69  BREAK THE CYCLE Fight to survive as this award...  40.19           -33%
# 70  FINAL FANTASY X/X-2 HD Remaster celebrates two...  11.99           -60%
# 71  Winner of more than 200 Game of the Year Award...   9.99           -75%
# 72  Command or corrupt an entire galaxy in the def...   6.99           -65%
# 73  Take the journey, now in ultimate quality. Boa...  13.99           -60%
# 74  Dead by Daylight is a multiplayer (4vs1) horro...   7.99           -60%
# 75  Join the rise of Darth Vader’s elite 501st Leg...   3.49           -65%
# 77  Developed in cooperation between Square Enix a...  23.99           -40%
# 78  The world is a vast, beautiful and dangerous p...  26.79           -33%
# 79  Play solo or in up to 10-player multiplayer co...   8.49           -66%
# 80  Kick Some Brick in I through VI! Play through ...   4.99           -75%
# 81  Bendy and the Dark Revival® is a first-person ...   5.99           -80%
# 82  A game that will show gamers the deepest, dark...   6.99           -65%
# 83  Thymesia is a gruelling action-RPG with fast-p...  14.99           -40%
# 84  The Great War is over - the fight continues. C...  26.39           -34%
# 85  Bethesda Game Studios welcome you to Fallout 7...   9.99           -75%
#
#               recentReviews               allReviews
# 0   Overwhelmingly Positive  Overwhelmingly Positive
# 1             Very Positive            Very Positive
# 2   Overwhelmingly Positive  Overwhelmingly Positive
# 3             Very Positive            Very Positive
# 4           Mostly Positive          Mostly Positive
# 5             Very Positive            Very Positive
# 6             Very Positive            Very Positive
# 7             Very Positive            Very Positive
# 8             Very Positive            Very Positive
# 9             Very Positive            Very Positive
# 10            Very Positive            Very Positive
# 11            Very Positive            Very Positive
# 12          Mostly Positive          Mostly Positive
# 14          Mostly Positive          Mostly Positive
# 15            Very Positive            Very Positive
# 16          Mostly Positive          Mostly Positive
# 17            Very Positive            Very Positive
# 18            Very Positive            Very Positive
# 19            Very Positive            Very Positive
# 23          Mostly Positive          Mostly Positive
# 49          Mostly Positive          Mostly Positive
# 50            Very Positive            Very Positive
# 51  Overwhelmingly Positive  Overwhelmingly Positive
# 53            Very Positive            Very Positive
# 54            Very Positive            Very Positive
# 55            Very Positive            Very Positive
# 56            Very Positive            Very Positive
# 57            Very Positive            Very Positive
# 58  Overwhelmingly Positive  Overwhelmingly Positive
# 59            Very Positive            Very Positive
# 60            Very Positive            Very Positive
# 61            Very Positive            Very Positive
# 62  Overwhelmingly Positive  Overwhelmingly Positive
# 63            Very Positive            Very Positive
# 64            Very Positive            Very Positive
# 65            Very Positive            Very Positive
# 66            Very Positive            Very Positive
# 67          Mostly Positive          Mostly Positive
# 69            Very Positive            Very Positive
# 70            Very Positive            Very Positive
# 71            Very Positive            Very Positive
# 72  Overwhelmingly Positive  Overwhelmingly Positive
# 73            Very Positive            Very Positive
# 74            Very Positive            Very Positive
# 75            Very Positive            Very Positive
# 77            Very Positive            Very Positive
# 78            Very Positive            Very Positive
# 79            Very Positive            Very Positive
# 80  Overwhelmingly Positive  Overwhelmingly Positive
# 81            Very Positive            Very Positive
# 82            Very Positive            Very Positive
# 83            Very Positive            Very Positive
# 84            Very Positive            Very Positive
# 85          Mostly Positive          Mostly Positive

# %% [markdown]
# ## Eliminando columnas que no utilizamos

# %% [markdown]
# En este apartado veremos como eliminar columnas que no necesitamos en nuestro dataset

# %%
df_nuevo= df_nuevo.drop(columns=['description'])
df_nuevo
# Out:
#                                                 title  price salePercentage  \
# 0                       Ori and the Will of the Wisps   9.89           -67%
# 1   Flashing Lights - Police, Firefighting, Emerge...   8.49           -66%
# 2                                          Thronefall   5.24           -25%
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...  23.99           -40%
# 4                                             UNDYING  13.99           -30%
# 5                          Headbangers: Rhythm Royale  13.39           -33%
# 6                          Bendy and the Dark Revival   5.99           -80%
# 7                                             CARRION   5.99           -70%
# 8                                            Thymesia  14.99           -40%
# 9                               Boxes: Lost Fragments  13.49           -10%
# 10                                           HELLCARD  15.79           -21%
# 11                                        Moonbreaker  22.49           -25%
# 12                            BlazBlue Entropy Effect  17.15           -22%
# 14                                       Ready or Not  37.49           -25%
# 15                FINAL FANTASY VII REMAKE INTERGRADE  34.99           -50%
# 16                                          Destiny 2  14.99           -75%
# 17                                    Hogwarts Legacy  35.99           -40%
# 18                                   Dead by Daylight   7.99           -60%
# 19                                     Hell Let Loose  42.24           -35%
# 23                                      Halo Infinite  23.99           -60%
# 49                                       Ready or Not  37.49           -25%
# 50                FINAL FANTASY VII REMAKE INTERGRADE  34.99           -50%
# 51                                         God of War  24.99           -50%
# 53                                    Hogwarts Legacy  35.99           -40%
# 54                     Marvel’s Spider-Man Remastered  35.99           -40%
# 55                 Marvel’s Spider-Man: Miles Morales  29.99           -40%
# 56                                          Days Gone  12.49           -75%
# 57                        Ratchet & Clank: Rift Apart  40.19           -33%
# 58                      Ori and the Will of the Wisps   9.89           -67%
# 59  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...  23.99           -40%
# 60            CRISIS CORE –FINAL FANTASY VII– REUNION  29.99           -40%
# 61           UNCHARTED™: Legacy of Thieves Collection  24.99           -50%
# 62                                         Thronefall   5.24           -25%
# 63                                      Overcooked! 2   6.24           -75%
# 64                                         Dead Space  23.99           -60%
# 65                                            CARRION   5.99           -70%
# 66                   FINAL FANTASY XII THE ZODIAC AGE  19.99           -60%
# 67                                       Atomic Heart  29.99           -50%
# 69                                          Returnal™  40.19           -33%
# 70                    FINAL FANTASY X/X-2 HD Remaster  11.99           -60%
# 71        The Elder Scrolls V: Skyrim Special Edition   9.99           -75%
# 72               STAR WARS™ Empire at War - Gold Pack   6.99           -65%
# 73                   FINAL FANTASY XV WINDOWS EDITION  13.99           -60%
# 74                                   Dead by Daylight   7.99           -60%
# 75           Star Wars: Battlefront 2 (Classic, 2005)   3.49           -65%
# 77          STRANGER OF PARADISE FINAL FANTASY ORIGIN  23.99           -40%
# 78                                           Grounded  26.79           -33%
# 79  Flashing Lights - Police, Firefighting, Emerge...   8.49           -66%
# 80               LEGO® Star Wars™ - The Complete Saga   4.99           -75%
# 81                         Bendy and the Dark Revival   5.99           -80%
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...   6.99           -65%
# 83                                           Thymesia  14.99           -40%
# 84                                    Last Train Home  26.39           -34%
# 85                                         Fallout 76   9.99           -75%
#
#               recentReviews               allReviews
# 0   Overwhelmingly Positive  Overwhelmingly Positive
# 1             Very Positive            Very Positive
# 2   Overwhelmingly Positive  Overwhelmingly Positive
# 3             Very Positive            Very Positive
# 4           Mostly Positive          Mostly Positive
# 5             Very Positive            Very Positive
# 6             Very Positive            Very Positive
# 7             Very Positive            Very Positive
# 8             Very Positive            Very Positive
# 9             Very Positive            Very Positive
# 10            Very Positive            Very Positive
# 11            Very Positive            Very Positive
# 12          Mostly Positive          Mostly Positive
# 14          Mostly Positive          Mostly Positive
# 15            Very Positive            Very Positive
# 16          Mostly Positive          Mostly Positive
# 17            Very Positive            Very Positive
# 18            Very Positive            Very Positive
# 19            Very Positive            Very Positive
# 23          Mostly Positive          Mostly Positive
# 49          Mostly Positive          Mostly Positive
# 50            Very Positive            Very Positive
# 51  Overwhelmingly Positive  Overwhelmingly Positive
# 53            Very Positive            Very Positive
# 54            Very Positive            Very Positive
# 55            Very Positive            Very Positive
# 56            Very Positive            Very Positive
# 57            Very Positive            Very Positive
# 58  Overwhelmingly Positive  Overwhelmingly Positive
# 59            Very Positive            Very Positive
# 60            Very Positive            Very Positive
# 61            Very Positive            Very Positive
# 62  Overwhelmingly Positive  Overwhelmingly Positive
# 63            Very Positive            Very Positive
# 64            Very Positive            Very Positive
# 65            Very Positive            Very Positive
# 66            Very Positive            Very Positive
# 67          Mostly Positive          Mostly Positive
# 69            Very Positive            Very Positive
# 70            Very Positive            Very Positive
# 71            Very Positive            Very Positive
# 72  Overwhelmingly Positive  Overwhelmingly Positive
# 73            Very Positive            Very Positive
# 74            Very Positive            Very Positive
# 75            Very Positive            Very Positive
# 77            Very Positive            Very Positive
# 78            Very Positive            Very Positive
# 79            Very Positive            Very Positive
# 80  Overwhelmingly Positive  Overwhelmingly Positive
# 81            Very Positive            Very Positive
# 82            Very Positive            Very Positive
# 83            Very Positive            Very Positive
# 84            Very Positive            Very Positive
# 85          Mostly Positive          Mostly Positive

# %% [markdown]
# Y con el .dropna ya hemos eliminado la columna " Descripcion " ya que no la necesitaremos para mas adelante

# %% [markdown]
# ## Renombrando columnas

# %% [markdown]
# En este apartado veremos como renombrar las columnas de nuestro data set, utilizando el .rename

# %%
df_final = df_nuevo.rename(columns={'title':'Titulo','price':'Precio','salePercentage':'Porcentaje_Venta', 'allReviews':'Total_Reviews', 'recentReviews':'Reviews_Recientes' })

# %% [markdown]
# Ahora una vez cambiado el nombre de las columnas previamente utilizando un diccionario para acortar el codigo.
# Y ahora volvemos a mostrar nuestro dataset con las columnas ya cambiadas

# %%
df_final
# Out:
#                                                Titulo  Precio  \
# 0                       Ori and the Will of the Wisps    9.89
# 1   Flashing Lights - Police, Firefighting, Emerge...    8.49
# 2                                          Thronefall    5.24
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 4                                             UNDYING   13.99
# 5                          Headbangers: Rhythm Royale   13.39
# 6                          Bendy and the Dark Revival    5.99
# 7                                             CARRION    5.99
# 8                                            Thymesia   14.99
# 9                               Boxes: Lost Fragments   13.49
# 10                                           HELLCARD   15.79
# 11                                        Moonbreaker   22.49
# 12                            BlazBlue Entropy Effect   17.15
# 14                                       Ready or Not   37.49
# 15                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 16                                          Destiny 2   14.99
# 17                                    Hogwarts Legacy   35.99
# 18                                   Dead by Daylight    7.99
# 19                                     Hell Let Loose   42.24
# 23                                      Halo Infinite   23.99
# 49                                       Ready or Not   37.49
# 50                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 51                                         God of War   24.99
# 53                                    Hogwarts Legacy   35.99
# 54                     Marvel’s Spider-Man Remastered   35.99
# 55                 Marvel’s Spider-Man: Miles Morales   29.99
# 56                                          Days Gone   12.49
# 57                        Ratchet & Clank: Rift Apart   40.19
# 58                      Ori and the Will of the Wisps    9.89
# 59  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 60            CRISIS CORE –FINAL FANTASY VII– REUNION   29.99
# 61           UNCHARTED™: Legacy of Thieves Collection   24.99
# 62                                         Thronefall    5.24
# 63                                      Overcooked! 2    6.24
# 64                                         Dead Space   23.99
# 65                                            CARRION    5.99
# 66                   FINAL FANTASY XII THE ZODIAC AGE   19.99
# 67                                       Atomic Heart   29.99
# 69                                          Returnal™   40.19
# 70                    FINAL FANTASY X/X-2 HD Remaster   11.99
# 71        The Elder Scrolls V: Skyrim Special Edition    9.99
# 72               STAR WARS™ Empire at War - Gold Pack    6.99
# 73                   FINAL FANTASY XV WINDOWS EDITION   13.99
# 74                                   Dead by Daylight    7.99
# 75           Star Wars: Battlefront 2 (Classic, 2005)    3.49
# 77          STRANGER OF PARADISE FINAL FANTASY ORIGIN   23.99
# 78                                           Grounded   26.79
# 79  Flashing Lights - Police, Firefighting, Emerge...    8.49
# 80               LEGO® Star Wars™ - The Complete Saga    4.99
# 81                         Bendy and the Dark Revival    5.99
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...    6.99
# 83                                           Thymesia   14.99
# 84                                    Last Train Home   26.39
# 85                                         Fallout 76    9.99
#
#    Porcentaje_Venta        Reviews_Recientes            Total_Reviews
# 0              -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 1              -66%            Very Positive            Very Positive
# 2              -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 3              -40%            Very Positive            Very Positive
# 4              -30%          Mostly Positive          Mostly Positive
# 5              -33%            Very Positive            Very Positive
# 6              -80%            Very Positive            Very Positive
# 7              -70%            Very Positive            Very Positive
# 8              -40%            Very Positive            Very Positive
# 9              -10%            Very Positive            Very Positive
# 10             -21%            Very Positive            Very Positive
# 11             -25%            Very Positive            Very Positive
# 12             -22%          Mostly Positive          Mostly Positive
# 14             -25%          Mostly Positive          Mostly Positive
# 15             -50%            Very Positive            Very Positive
# 16             -75%          Mostly Positive          Mostly Positive
# 17             -40%            Very Positive            Very Positive
# 18             -60%            Very Positive            Very Positive
# 19             -35%            Very Positive            Very Positive
# 23             -60%          Mostly Positive          Mostly Positive
# 49             -25%          Mostly Positive          Mostly Positive
# 50             -50%            Very Positive            Very Positive
# 51             -50%  Overwhelmingly Positive  Overwhelmingly Positive
# 53             -40%            Very Positive            Very Positive
# 54             -40%            Very Positive            Very Positive
# 55             -40%            Very Positive            Very Positive
# 56             -75%            Very Positive            Very Positive
# 57             -33%            Very Positive            Very Positive
# 58             -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 59             -40%            Very Positive            Very Positive
# 60             -40%            Very Positive            Very Positive
# 61             -50%            Very Positive            Very Positive
# 62             -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 63             -75%            Very Positive            Very Positive
# 64             -60%            Very Positive            Very Positive
# 65             -70%            Very Positive            Very Positive
# 66             -60%            Very Positive            Very Positive
# 67             -50%          Mostly Positive          Mostly Positive
# 69             -33%            Very Positive            Very Positive
# 70             -60%            Very Positive            Very Positive
# 71             -75%            Very Positive            Very Positive
# 72             -65%  Overwhelmingly Positive  Overwhelmingly Positive
# 73             -60%            Very Positive            Very Positive
# 74             -60%            Very Positive            Very Positive
# 75             -65%            Very Positive            Very Positive
# 77             -40%            Very Positive            Very Positive
# 78             -33%            Very Positive            Very Positive
# 79             -66%            Very Positive            Very Positive
# 80             -75%  Overwhelmingly Positive  Overwhelmingly Positive
# 81             -80%            Very Positive            Very Positive
# 82             -65%            Very Positive            Very Positive
# 83             -40%            Very Positive            Very Positive
# 84             -34%            Very Positive            Very Positive
# 85             -75%          Mostly Positive          Mostly Positive

# %% [markdown]
# ## Reindexaciones

# %% [markdown]
# Ahora veremos las reindexaciones, estas son usadas cuando alguna columa es alterada o eliminada, y dando asi que los index esten mal posicionados, de modo si eliminamos el index 2, la tabla mostrara 1,3,4,5

# %%
df_final_2 = df_final.copy()

# %%
df_final_2
# Out:
#                                                Titulo  Precio  \
# 0                       Ori and the Will of the Wisps    9.89
# 1   Flashing Lights - Police, Firefighting, Emerge...    8.49
# 2                                          Thronefall    5.24
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 4                                             UNDYING   13.99
# 5                          Headbangers: Rhythm Royale   13.39
# 6                          Bendy and the Dark Revival    5.99
# 7                                             CARRION    5.99
# 8                                            Thymesia   14.99
# 9                               Boxes: Lost Fragments   13.49
# 10                                           HELLCARD   15.79
# 11                                        Moonbreaker   22.49
# 12                            BlazBlue Entropy Effect   17.15
# 14                                       Ready or Not   37.49
# 15                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 16                                          Destiny 2   14.99
# 17                                    Hogwarts Legacy   35.99
# 18                                   Dead by Daylight    7.99
# 19                                     Hell Let Loose   42.24
# 23                                      Halo Infinite   23.99
# 49                                       Ready or Not   37.49
# 50                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 51                                         God of War   24.99
# 53                                    Hogwarts Legacy   35.99
# 54                     Marvel’s Spider-Man Remastered   35.99
# 55                 Marvel’s Spider-Man: Miles Morales   29.99
# 56                                          Days Gone   12.49
# 57                        Ratchet & Clank: Rift Apart   40.19
# 58                      Ori and the Will of the Wisps    9.89
# 59  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 60            CRISIS CORE –FINAL FANTASY VII– REUNION   29.99
# 61           UNCHARTED™: Legacy of Thieves Collection   24.99
# 62                                         Thronefall    5.24
# 63                                      Overcooked! 2    6.24
# 64                                         Dead Space   23.99
# 65                                            CARRION    5.99
# 66                   FINAL FANTASY XII THE ZODIAC AGE   19.99
# 67                                       Atomic Heart   29.99
# 69                                          Returnal™   40.19
# 70                    FINAL FANTASY X/X-2 HD Remaster   11.99
# 71        The Elder Scrolls V: Skyrim Special Edition    9.99
# 72               STAR WARS™ Empire at War - Gold Pack    6.99
# 73                   FINAL FANTASY XV WINDOWS EDITION   13.99
# 74                                   Dead by Daylight    7.99
# 75           Star Wars: Battlefront 2 (Classic, 2005)    3.49
# 77          STRANGER OF PARADISE FINAL FANTASY ORIGIN   23.99
# 78                                           Grounded   26.79
# 79  Flashing Lights - Police, Firefighting, Emerge...    8.49
# 80               LEGO® Star Wars™ - The Complete Saga    4.99
# 81                         Bendy and the Dark Revival    5.99
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...    6.99
# 83                                           Thymesia   14.99
# 84                                    Last Train Home   26.39
# 85                                         Fallout 76    9.99
#
#    Porcentaje_Venta        Reviews_Recientes            Total_Reviews
# 0              -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 1              -66%            Very Positive            Very Positive
# 2              -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 3              -40%            Very Positive            Very Positive
# 4              -30%          Mostly Positive          Mostly Positive
# 5              -33%            Very Positive            Very Positive
# 6              -80%            Very Positive            Very Positive
# 7              -70%            Very Positive            Very Positive
# 8              -40%            Very Positive            Very Positive
# 9              -10%            Very Positive            Very Positive
# 10             -21%            Very Positive            Very Positive
# 11             -25%            Very Positive            Very Positive
# 12             -22%          Mostly Positive          Mostly Positive
# 14             -25%          Mostly Positive          Mostly Positive
# 15             -50%            Very Positive            Very Positive
# 16             -75%          Mostly Positive          Mostly Positive
# 17             -40%            Very Positive            Very Positive
# 18             -60%            Very Positive            Very Positive
# 19             -35%            Very Positive            Very Positive
# 23             -60%          Mostly Positive          Mostly Positive
# 49             -25%          Mostly Positive          Mostly Positive
# 50             -50%            Very Positive            Very Positive
# 51             -50%  Overwhelmingly Positive  Overwhelmingly Positive
# 53             -40%            Very Positive            Very Positive
# 54             -40%            Very Positive            Very Positive
# 55             -40%            Very Positive            Very Positive
# 56             -75%            Very Positive            Very Positive
# 57             -33%            Very Positive            Very Positive
# 58             -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 59             -40%            Very Positive            Very Positive
# 60             -40%            Very Positive            Very Positive
# 61             -50%            Very Positive            Very Positive
# 62             -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 63             -75%            Very Positive            Very Positive
# 64             -60%            Very Positive            Very Positive
# 65             -70%            Very Positive            Very Positive
# 66             -60%            Very Positive            Very Positive
# 67             -50%          Mostly Positive          Mostly Positive
# 69             -33%            Very Positive            Very Positive
# 70             -60%            Very Positive            Very Positive
# 71             -75%            Very Positive            Very Positive
# 72             -65%  Overwhelmingly Positive  Overwhelmingly Positive
# 73             -60%            Very Positive            Very Positive
# 74             -60%            Very Positive            Very Positive
# 75             -65%            Very Positive            Very Positive
# 77             -40%            Very Positive            Very Positive
# 78             -33%            Very Positive            Very Positive
# 79             -66%            Very Positive            Very Positive
# 80             -75%  Overwhelmingly Positive  Overwhelmingly Positive
# 81             -80%            Very Positive            Very Positive
# 82             -65%            Very Positive            Very Positive
# 83             -40%            Very Positive            Very Positive
# 84             -34%            Very Positive            Very Positive
# 85             -75%          Mostly Positive          Mostly Positive

# %% [markdown]
# En este apartado veremos como solucionar los index, usando las indexaciones con el .set_index

# %%
df_final_2.set_index('Titulo', inplace=True)

# %%
df_final_2
# Out:
#                                                     Precio Porcentaje_Venta  \
# Titulo
# Ori and the Will of the Wisps                         9.89             -67%
# Flashing Lights - Police, Firefighting, Emergen...    8.49             -66%
# Thronefall                                            5.24             -25%
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...   23.99             -40%
# UNDYING                                              13.99             -30%
# Headbangers: Rhythm Royale                           13.39             -33%
# Bendy and the Dark Revival                            5.99             -80%
# CARRION                                               5.99             -70%
# Thymesia                                             14.99             -40%
# Boxes: Lost Fragments                                13.49             -10%
# HELLCARD                                             15.79             -21%
# Moonbreaker                                          22.49             -25%
# BlazBlue Entropy Effect                              17.15             -22%
# Ready or Not                                         37.49             -25%
# FINAL FANTASY VII REMAKE INTERGRADE                  34.99             -50%
# Destiny 2                                            14.99             -75%
# Hogwarts Legacy                                      35.99             -40%
# Dead by Daylight                                      7.99             -60%
# Hell Let Loose                                       42.24             -35%
# Halo Infinite                                        23.99             -60%
# Ready or Not                                         37.49             -25%
# FINAL FANTASY VII REMAKE INTERGRADE                  34.99             -50%
# God of War                                           24.99             -50%
# Hogwarts Legacy                                      35.99             -40%
# Marvel’s Spider-Man Remastered                       35.99             -40%
# Marvel’s Spider-Man: Miles Morales                   29.99             -40%
# Days Gone                                            12.49             -75%
# Ratchet & Clank: Rift Apart                          40.19             -33%
# Ori and the Will of the Wisps                         9.89             -67%
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...   23.99             -40%
# CRISIS CORE –FINAL FANTASY VII– REUNION              29.99             -40%
# UNCHARTED™: Legacy of Thieves Collection             24.99             -50%
# Thronefall                                            5.24             -25%
# Overcooked! 2                                         6.24             -75%
# Dead Space                                           23.99             -60%
# CARRION                                               5.99             -70%
# FINAL FANTASY XII THE ZODIAC AGE                     19.99             -60%
# Atomic Heart                                         29.99             -50%
# Returnal™                                            40.19             -33%
# FINAL FANTASY X/X-2 HD Remaster                      11.99             -60%
# The Elder Scrolls V: Skyrim Special Edition           9.99             -75%
# STAR WARS™ Empire at War - Gold Pack                  6.99             -65%
# FINAL FANTASY XV WINDOWS EDITION                     13.99             -60%
# Dead by Daylight                                      7.99             -60%
# Star Wars: Battlefront 2 (Classic, 2005)              3.49             -65%
# STRANGER OF PARADISE FINAL FANTASY ORIGIN            23.99             -40%
# Grounded                                             26.79             -33%
# Flashing Lights - Police, Firefighting, Emergen...    8.49             -66%
# LEGO® Star Wars™ - The Complete Saga                  4.99             -75%
# Bendy and the Dark Revival                            5.99             -80%
# STAR WARS™ - The Force Unleashed™ Ultimate Sith...    6.99             -65%
# Thymesia                                             14.99             -40%
# Last Train Home                                      26.39             -34%
# Fallout 76                                            9.99             -75%
#
#                                                           Reviews_Recientes  \
# Titulo
# Ori and the Will of the Wisps                       Overwhelmingly Positive
# Flashing Lights - Police, Firefighting, Emergen...            Very Positive
# Thronefall                                          Overwhelmingly Positive
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...            Very Positive
# UNDYING                                                     Mostly Positive
# Headbangers: Rhythm Royale                                    Very Positive
# Bendy and the Dark Revival                                    Very Positive
# CARRION                                                       Very Positive
# Thymesia                                                      Very Positive
# Boxes: Lost Fragments                                         Very Positive
# HELLCARD                                                      Very Positive
# Moonbreaker                                                   Very Positive
# BlazBlue Entropy Effect                                     Mostly Positive
# Ready or Not                                                Mostly Positive
# FINAL FANTASY VII REMAKE INTERGRADE                           Very Positive
# Destiny 2                                                   Mostly Positive
# Hogwarts Legacy                                               Very Positive
# Dead by Daylight                                              Very Positive
# Hell Let Loose                                                Very Positive
# Halo Infinite                                               Mostly Positive
# Ready or Not                                                Mostly Positive
# FINAL FANTASY VII REMAKE INTERGRADE                           Very Positive
# God of War                                          Overwhelmingly Positive
# Hogwarts Legacy                                               Very Positive
# Marvel’s Spider-Man Remastered                                Very Positive
# Marvel’s Spider-Man: Miles Morales                            Very Positive
# Days Gone                                                     Very Positive
# Ratchet & Clank: Rift Apart                                   Very Positive
# Ori and the Will of the Wisps                       Overwhelmingly Positive
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...            Very Positive
# CRISIS CORE –FINAL FANTASY VII– REUNION                       Very Positive
# UNCHARTED™: Legacy of Thieves Collection                      Very Positive
# Thronefall                                          Overwhelmingly Positive
# Overcooked! 2                                                 Very Positive
# Dead Space                                                    Very Positive
# CARRION                                                       Very Positive
# FINAL FANTASY XII THE ZODIAC AGE                              Very Positive
# Atomic Heart                                                Mostly Positive
# Returnal™                                                     Very Positive
# FINAL FANTASY X/X-2 HD Remaster                               Very Positive
# The Elder Scrolls V: Skyrim Special Edition                   Very Positive
# STAR WARS™ Empire at War - Gold Pack                Overwhelmingly Positive
# FINAL FANTASY XV WINDOWS EDITION                              Very Positive
# Dead by Daylight                                              Very Positive
# Star Wars: Battlefront 2 (Classic, 2005)                      Very Positive
# STRANGER OF PARADISE FINAL FANTASY ORIGIN                     Very Positive
# Grounded                                                      Very Positive
# Flashing Lights - Police, Firefighting, Emergen...            Very Positive
# LEGO® Star Wars™ - The Complete Saga                Overwhelmingly Positive
# Bendy and the Dark Revival                                    Very Positive
# STAR WARS™ - The Force Unleashed™ Ultimate Sith...            Very Positive
# Thymesia                                                      Very Positive
# Last Train Home                                               Very Positive
# Fallout 76                                                  Mostly Positive
#
#                                                               Total_Reviews
# Titulo
# Ori and the Will of the Wisps                       Overwhelmingly Positive
# Flashing Lights - Police, Firefighting, Emergen...            Very Positive
# Thronefall                                          Overwhelmingly Positive
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...            Very Positive
# UNDYING                                                     Mostly Positive
# Headbangers: Rhythm Royale                                    Very Positive
# Bendy and the Dark Revival                                    Very Positive
# CARRION                                                       Very Positive
# Thymesia                                                      Very Positive
# Boxes: Lost Fragments                                         Very Positive
# HELLCARD                                                      Very Positive
# Moonbreaker                                                   Very Positive
# BlazBlue Entropy Effect                                     Mostly Positive
# Ready or Not                                                Mostly Positive
# FINAL FANTASY VII REMAKE INTERGRADE                           Very Positive
# Destiny 2                                                   Mostly Positive
# Hogwarts Legacy                                               Very Positive
# Dead by Daylight                                              Very Positive
# Hell Let Loose                                                Very Positive
# Halo Infinite                                               Mostly Positive
# Ready or Not                                                Mostly Positive
# FINAL FANTASY VII REMAKE INTERGRADE                           Very Positive
# God of War                                          Overwhelmingly Positive
# Hogwarts Legacy                                               Very Positive
# Marvel’s Spider-Man Remastered                                Very Positive
# Marvel’s Spider-Man: Miles Morales                            Very Positive
# Days Gone                                                     Very Positive
# Ratchet & Clank: Rift Apart                                   Very Positive
# Ori and the Will of the Wisps                       Overwhelmingly Positive
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...            Very Positive
# CRISIS CORE –FINAL FANTASY VII– REUNION                       Very Positive
# UNCHARTED™: Legacy of Thieves Collection                      Very Positive
# Thronefall                                          Overwhelmingly Positive
# Overcooked! 2                                                 Very Positive
# Dead Space                                                    Very Positive
# CARRION                                                       Very Positive
# FINAL FANTASY XII THE ZODIAC AGE                              Very Positive
# Atomic Heart                                                Mostly Positive
# Returnal™                                                     Very Positive
# FINAL FANTASY X/X-2 HD Remaster                               Very Positive
# The Elder Scrolls V: Skyrim Special Edition                   Very Positive
# STAR WARS™ Empire at War - Gold Pack                Overwhelmingly Positive
# FINAL FANTASY XV WINDOWS EDITION                              Very Positive
# Dead by Daylight                                              Very Positive
# Star Wars: Battlefront 2 (Classic, 2005)                      Very Positive
# STRANGER OF PARADISE FINAL FANTASY ORIGIN                     Very Positive
# Grounded                                                      Very Positive
# Flashing Lights - Police, Firefighting, Emergen...            Very Positive
# LEGO® Star Wars™ - The Complete Saga                Overwhelmingly Positive
# Bendy and the Dark Revival                                    Very Positive
# STAR WARS™ - The Force Unleashed™ Ultimate Sith...            Very Positive
# Thymesia                                                      Very Positive
# Last Train Home                                               Very Positive
# Fallout 76                                                  Mostly Positive

# %% [markdown]
# En este apartado veremos con el .reset_index es utilizado para resetear los index ya previamente arreglados

# %%
df_final_2.reset_index(inplace=True)

# %%
df_final_2
# Out:
#                                                Titulo  Precio  \
# 0                       Ori and the Will of the Wisps    9.89
# 1   Flashing Lights - Police, Firefighting, Emerge...    8.49
# 2                                          Thronefall    5.24
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 4                                             UNDYING   13.99
# 5                          Headbangers: Rhythm Royale   13.39
# 6                          Bendy and the Dark Revival    5.99
# 7                                             CARRION    5.99
# 8                                            Thymesia   14.99
# 9                               Boxes: Lost Fragments   13.49
# 10                                           HELLCARD   15.79
# 11                                        Moonbreaker   22.49
# 12                            BlazBlue Entropy Effect   17.15
# 13                                       Ready or Not   37.49
# 14                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 15                                          Destiny 2   14.99
# 16                                    Hogwarts Legacy   35.99
# 17                                   Dead by Daylight    7.99
# 18                                     Hell Let Loose   42.24
# 19                                      Halo Infinite   23.99
# 20                                       Ready or Not   37.49
# 21                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 22                                         God of War   24.99
# 23                                    Hogwarts Legacy   35.99
# 24                     Marvel’s Spider-Man Remastered   35.99
# 25                 Marvel’s Spider-Man: Miles Morales   29.99
# 26                                          Days Gone   12.49
# 27                        Ratchet & Clank: Rift Apart   40.19
# 28                      Ori and the Will of the Wisps    9.89
# 29  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 30            CRISIS CORE –FINAL FANTASY VII– REUNION   29.99
# 31           UNCHARTED™: Legacy of Thieves Collection   24.99
# 32                                         Thronefall    5.24
# 33                                      Overcooked! 2    6.24
# 34                                         Dead Space   23.99
# 35                                            CARRION    5.99
# 36                   FINAL FANTASY XII THE ZODIAC AGE   19.99
# 37                                       Atomic Heart   29.99
# 38                                          Returnal™   40.19
# 39                    FINAL FANTASY X/X-2 HD Remaster   11.99
# 40        The Elder Scrolls V: Skyrim Special Edition    9.99
# 41               STAR WARS™ Empire at War - Gold Pack    6.99
# 42                   FINAL FANTASY XV WINDOWS EDITION   13.99
# 43                                   Dead by Daylight    7.99
# 44           Star Wars: Battlefront 2 (Classic, 2005)    3.49
# 45          STRANGER OF PARADISE FINAL FANTASY ORIGIN   23.99
# 46                                           Grounded   26.79
# 47  Flashing Lights - Police, Firefighting, Emerge...    8.49
# 48               LEGO® Star Wars™ - The Complete Saga    4.99
# 49                         Bendy and the Dark Revival    5.99
# 50  STAR WARS™ - The Force Unleashed™ Ultimate Sit...    6.99
# 51                                           Thymesia   14.99
# 52                                    Last Train Home   26.39
# 53                                         Fallout 76    9.99
#
#    Porcentaje_Venta        Reviews_Recientes            Total_Reviews
# 0              -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 1              -66%            Very Positive            Very Positive
# 2              -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 3              -40%            Very Positive            Very Positive
# 4              -30%          Mostly Positive          Mostly Positive
# 5              -33%            Very Positive            Very Positive
# 6              -80%            Very Positive            Very Positive
# 7              -70%            Very Positive            Very Positive
# 8              -40%            Very Positive            Very Positive
# 9              -10%            Very Positive            Very Positive
# 10             -21%            Very Positive            Very Positive
# 11             -25%            Very Positive            Very Positive
# 12             -22%          Mostly Positive          Mostly Positive
# 13             -25%          Mostly Positive          Mostly Positive
# 14             -50%            Very Positive            Very Positive
# 15             -75%          Mostly Positive          Mostly Positive
# 16             -40%            Very Positive            Very Positive
# 17             -60%            Very Positive            Very Positive
# 18             -35%            Very Positive            Very Positive
# 19             -60%          Mostly Positive          Mostly Positive
# 20             -25%          Mostly Positive          Mostly Positive
# 21             -50%            Very Positive            Very Positive
# 22             -50%  Overwhelmingly Positive  Overwhelmingly Positive
# 23             -40%            Very Positive            Very Positive
# 24             -40%            Very Positive            Very Positive
# 25             -40%            Very Positive            Very Positive
# 26             -75%            Very Positive            Very Positive
# 27             -33%            Very Positive            Very Positive
# 28             -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 29             -40%            Very Positive            Very Positive
# 30             -40%            Very Positive            Very Positive
# 31             -50%            Very Positive            Very Positive
# 32             -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 33             -75%            Very Positive            Very Positive
# 34             -60%            Very Positive            Very Positive
# 35             -70%            Very Positive            Very Positive
# 36             -60%            Very Positive            Very Positive
# 37             -50%          Mostly Positive          Mostly Positive
# 38             -33%            Very Positive            Very Positive
# 39             -60%            Very Positive            Very Positive
# 40             -75%            Very Positive            Very Positive
# 41             -65%  Overwhelmingly Positive  Overwhelmingly Positive
# 42             -60%            Very Positive            Very Positive
# 43             -60%            Very Positive            Very Positive
# 44             -65%            Very Positive            Very Positive
# 45             -40%            Very Positive            Very Positive
# 46             -33%            Very Positive            Very Positive
# 47             -66%            Very Positive            Very Positive
# 48             -75%  Overwhelmingly Positive  Overwhelmingly Positive
# 49             -80%            Very Positive            Very Positive
# 50             -65%            Very Positive            Very Positive
# 51             -40%            Very Positive            Very Positive
# 52             -34%            Very Positive            Very Positive
# 53             -75%          Mostly Positive          Mostly Positive

# %% [markdown]
# ## Sacando la media

# %% [markdown]
# En este apartado veremos como sacar la media usando el .mean()

# %%
df_final_2['Precio'].mean()
# Out:
# 18.967037037037034

# %% [markdown]
# ## Sacando la mediana

# %% [markdown]
# En este apartado veremos como sacar la mediana utilizando el .meadian()

# %%
mediana_precio = df_final_2['Precio'].median()

# %%
mediana_precio
# Out:
# 14.99

# %% [markdown]
# ## Sacar la moda

# %% [markdown]
# En este apartado veremos como sacar la moda, del "price" utilizando el .mode()

# %%
moda_precio = df_final_2['Precio'].mode()

# %%
moda_precio
# Out:
# 0    23.99
# Name: Precio, dtype: float64

# %% [markdown]
# ## Desviacion Estandar

# %% [markdown]
# Ahora veremos la derivacion estandar en este caso del 'Precio'

# %%
df_final_2['Precio']
# Out:
# 0      9.89
# 1      8.49
# 2      5.24
# 3     23.99
# 4     13.99
# 5     13.39
# 6      5.99
# 7      5.99
# 8     14.99
# 9     13.49
# 10    15.79
# 11    22.49
# 12    17.15
# 13    37.49
# 14    34.99
# 15    14.99
# 16    35.99
# 17     7.99
# 18    42.24
# 19    23.99
# 20    37.49
# 21    34.99
# 22    24.99
# 23    35.99
# 24    35.99
# 25    29.99
# 26    12.49
# 27    40.19
# 28     9.89
# 29    23.99
# 30    29.99
# 31    24.99
# 32     5.24
# 33     6.24
# 34    23.99
# 35     5.99
# 36    19.99
# 37    29.99
# 38    40.19
# 39    11.99
# 40     9.99
# 41     6.99
# 42    13.99
# 43     7.99
# 44     3.49
# 45    23.99
# 46    26.79
# 47     8.49
# 48     4.99
# 49     5.99
# 50     6.99
# 51    14.99
# 52    26.39
# 53     9.99
# Name: Precio, dtype: float64

# %%
df_final_2['Precio'].mean()
# Out:
# 18.967037037037034

# %%
df_final_2['Precio'].std()
# Out:
# 11.645152142144674

# %% [markdown]
# ## Estadísticos de Orden

# %% [markdown]
# En este apartado veremos los estadisticos de orden, primero mostrando la tabla y sacando el maximo, mediana y los cuartiles desde
# 0.25 hasta 1

# %%
df_final_2.head()
# Out:
#                                               Titulo  Precio Porcentaje_Venta  \
# 0                      Ori and the Will of the Wisps    9.89             -67%
# 1  Flashing Lights - Police, Firefighting, Emerge...    8.49             -66%
# 2                                         Thronefall    5.24             -25%
# 3  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99             -40%
# 4                                            UNDYING   13.99             -30%
#
#          Reviews_Recientes            Total_Reviews
# 0  Overwhelmingly Positive  Overwhelmingly Positive
# 1            Very Positive            Very Positive
# 2  Overwhelmingly Positive  Overwhelmingly Positive
# 3            Very Positive            Very Positive
# 4          Mostly Positive          Mostly Positive

# %%
df_final_2['Precio'].max()
# Out:
# 42.24

# %%
df_final_2['Precio'].median()
# Out:
# 14.99

# %%
# Cuartil 2
Cuartil_1 = df_final_2['Precio'].quantile(0.5)
Cuartil_1
# Out:
# 14.99

# %%
# Cuartil 3
Cuartil_2 = df_final_2['Precio'].quantile(0.25)
Cuartil_2
# Out:
# 8.49

# %%
Cuartil_3 = df_final_2['Precio'].quantile(0.50)
Cuartil_3
# Out:
# 14.99

# %%
# Cuartil 4
Cuartil_4 = df_final_2['Precio'].quantile(0.75)
Cuartil_4
# Out:
# 26.689999999999998

# %%
Cuartil_5 = df_final_2['Precio'].quantile(1)
Cuartil_5
# Out:
# 42.24

# %% [markdown]
# ## Graficacion Boxplot

# %% [markdown]
# Hacemos la graficacion en boxplot, en estos casos no todas las tablas pueden funcionar para nuestro dataset, hay unas tablas que no nos sirven para representar de mejor manera nuestros datos.

# %% [markdown]
# Importamos pandas, seaborn y matplotlib ya que estas son las extenciones que vamos a necesitar

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_final_2
# Out:
#                                                Titulo  Precio  \
# 0                       Ori and the Will of the Wisps    9.89
# 1   Flashing Lights - Police, Firefighting, Emerge...    8.49
# 2                                          Thronefall    5.24
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 4                                             UNDYING   13.99
# 5                          Headbangers: Rhythm Royale   13.39
# 6                          Bendy and the Dark Revival    5.99
# 7                                             CARRION    5.99
# 8                                            Thymesia   14.99
# 9                               Boxes: Lost Fragments   13.49
# 10                                           HELLCARD   15.79
# 11                                        Moonbreaker   22.49
# 12                            BlazBlue Entropy Effect   17.15
# 13                                       Ready or Not   37.49
# 14                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 15                                          Destiny 2   14.99
# 16                                    Hogwarts Legacy   35.99
# 17                                   Dead by Daylight    7.99
# 18                                     Hell Let Loose   42.24
# 19                                      Halo Infinite   23.99
# 20                                       Ready or Not   37.49
# 21                FINAL FANTASY VII REMAKE INTERGRADE   34.99
# 22                                         God of War   24.99
# 23                                    Hogwarts Legacy   35.99
# 24                     Marvel’s Spider-Man Remastered   35.99
# 25                 Marvel’s Spider-Man: Miles Morales   29.99
# 26                                          Days Gone   12.49
# 27                        Ratchet & Clank: Rift Apart   40.19
# 28                      Ori and the Will of the Wisps    9.89
# 29  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 30            CRISIS CORE –FINAL FANTASY VII– REUNION   29.99
# 31           UNCHARTED™: Legacy of Thieves Collection   24.99
# 32                                         Thronefall    5.24
# 33                                      Overcooked! 2    6.24
# 34                                         Dead Space   23.99
# 35                                            CARRION    5.99
# 36                   FINAL FANTASY XII THE ZODIAC AGE   19.99
# 37                                       Atomic Heart   29.99
# 38                                          Returnal™   40.19
# 39                    FINAL FANTASY X/X-2 HD Remaster   11.99
# 40        The Elder Scrolls V: Skyrim Special Edition    9.99
# 41               STAR WARS™ Empire at War - Gold Pack    6.99
# 42                   FINAL FANTASY XV WINDOWS EDITION   13.99
# 43                                   Dead by Daylight    7.99
# 44           Star Wars: Battlefront 2 (Classic, 2005)    3.49
# 45          STRANGER OF PARADISE FINAL FANTASY ORIGIN   23.99
# 46                                           Grounded   26.79
# 47  Flashing Lights - Police, Firefighting, Emerge...    8.49
# 48               LEGO® Star Wars™ - The Complete Saga    4.99
# 49                         Bendy and the Dark Revival    5.99
# 50  STAR WARS™ - The Force Unleashed™ Ultimate Sit...    6.99
# 51                                           Thymesia   14.99
# 52                                    Last Train Home   26.39
# 53                                         Fallout 76    9.99
#
#    Porcentaje_Venta        Reviews_Recientes            Total_Reviews
# 0              -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 1              -66%            Very Positive            Very Positive
# 2              -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 3              -40%            Very Positive            Very Positive
# 4              -30%          Mostly Positive          Mostly Positive
# 5              -33%            Very Positive            Very Positive
# 6              -80%            Very Positive            Very Positive
# 7              -70%            Very Positive            Very Positive
# 8              -40%            Very Positive            Very Positive
# 9              -10%            Very Positive            Very Positive
# 10             -21%            Very Positive            Very Positive
# 11             -25%            Very Positive            Very Positive
# 12             -22%          Mostly Positive          Mostly Positive
# 13             -25%          Mostly Positive          Mostly Positive
# 14             -50%            Very Positive            Very Positive
# 15             -75%          Mostly Positive          Mostly Positive
# 16             -40%            Very Positive            Very Positive
# 17             -60%            Very Positive            Very Positive
# 18             -35%            Very Positive            Very Positive
# 19             -60%          Mostly Positive          Mostly Positive
# 20             -25%          Mostly Positive          Mostly Positive
# 21             -50%            Very Positive            Very Positive
# 22             -50%  Overwhelmingly Positive  Overwhelmingly Positive
# 23             -40%            Very Positive            Very Positive
# 24             -40%            Very Positive            Very Positive
# 25             -40%            Very Positive            Very Positive
# 26             -75%            Very Positive            Very Positive
# 27             -33%            Very Positive            Very Positive
# 28             -67%  Overwhelmingly Positive  Overwhelmingly Positive
# 29             -40%            Very Positive            Very Positive
# 30             -40%            Very Positive            Very Positive
# 31             -50%            Very Positive            Very Positive
# 32             -25%  Overwhelmingly Positive  Overwhelmingly Positive
# 33             -75%            Very Positive            Very Positive
# 34             -60%            Very Positive            Very Positive
# 35             -70%            Very Positive            Very Positive
# 36             -60%            Very Positive            Very Positive
# 37             -50%          Mostly Positive          Mostly Positive
# 38             -33%            Very Positive            Very Positive
# 39             -60%            Very Positive            Very Positive
# 40             -75%            Very Positive            Very Positive
# 41             -65%  Overwhelmingly Positive  Overwhelmingly Positive
# 42             -60%            Very Positive            Very Positive
# 43             -60%            Very Positive            Very Positive
# 44             -65%            Very Positive            Very Positive
# 45             -40%            Very Positive            Very Positive
# 46             -33%            Very Positive            Very Positive
# 47             -66%            Very Positive            Very Positive
# 48             -75%  Overwhelmingly Positive  Overwhelmingly Positive
# 49             -80%            Very Positive            Very Positive
# 50             -65%            Very Positive            Very Positive
# 51             -40%            Very Positive            Very Positive
# 52             -34%            Very Positive            Very Positive
# 53             -75%          Mostly Positive          Mostly Positive

# %% [markdown]
# En este apartado hicimos una tabla de pastel de la distribucion de reseñas de steam

# %%
# Contar las ocurrencias de cada categoría en la columna 'total_reviews'
conteo_reviews = df_final_2['Total_Reviews'].value_counts()

# Crear el gráfico de pastel
plt.figure(figsize=(10, 7))
plt.pie(conteo_reviews, labels=conteo_reviews.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(conteo_reviews))))

# Añadir título
plt.title('Distribución de Reseñas por Categoría')
plt.show()

# %% [markdown]
# ## Graficacion para Precios

# %% [markdown]
# Esta grafica la usamos para distribucion de precios utilizando la media, mediana y la moda para sacar los datos para la tabla

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# En este apartado eliminaremos el simbolo % ya que nos causa problemas para graficar las tablas, usaremos de nuevo el str.replace para hacerlo:

# %%
df_final_2['Porcentaje_Venta'] =df_final_2['Porcentaje_Venta'].str.replace('%',' ')

# %%
df_final_2.head()
# Out:
#                                               Titulo  Precio Porcentaje_Venta  \
# 0                      Ori and the Will of the Wisps    9.89             -67
# 1  Flashing Lights - Police, Firefighting, Emerge...    8.49             -66
# 2                                         Thronefall    5.24             -25
# 3  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99             -40
# 4                                            UNDYING   13.99             -30
#
#          Reviews_Recientes            Total_Reviews
# 0  Overwhelmingly Positive  Overwhelmingly Positive
# 1            Very Positive            Very Positive
# 2  Overwhelmingly Positive  Overwhelmingly Positive
# 3            Very Positive            Very Positive
# 4          Mostly Positive          Mostly Positive

# %%
df_final_2.shape
# Out:
# (54, 5)

# %%
media_precio = df_final_2['Precio'].mean()
media_precio
# Out:
# 18.967037037037034

# %%
mediana_precio
# Out:
# 14.99

# %%
moda_precio
# Out:
# 0    23.99
# Name: Precio, dtype: float64

# %% [markdown]
# En este apartado vemos como calcular la media, mediana y la moda y el codigo para añadir la tabla que necesitamos

# %%
# Calcular media, mediana y moda
media_precio = df_final_2['Precio'].mean()
mediana_precio = df_final_2['Precio'].median()
moda_precio = df_final_2['Precio'].mode()[0]

plt.figure(figsize=(10, 5))
sns.histplot(df_final_2['Precio'], bins=30, kde=True, color='g')

# Añadir líneas para la media, mediana y moda
plt.axvline(media_precio, color='r', linestyle='dashed', linewidth=2, label=f'Media: {media_precio:.2f}')
plt.axvline(mediana_precio, color='b', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_precio:.2f}')
plt.axvline(moda_precio, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_precio:.2f}')

# Añadir etiquetas y título
plt.xlabel('Precios')
plt.ylabel('Frecuencia')
plt.title('Distribución de Precios con Media, Mediana y Moda')
plt.legend()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Ahora tenemos la tabla lista con los datos que mencionamos

# %% [markdown]
# ## Graficacion Para Porcentaje de Ventas

# %% [markdown]
# En este apartado haremos otra tabla para los porcentaes de ventas de steam
# Usaremos numpy, matplotlib y seaborn para hacer la tabla y mas adelante veremos como realizamos esta tabla.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_final_2
# Out:
#                                                Titulo  Precio  \
# 0                       Ori and the Will of the Wisps    9.89
# 1   Flashing Lights - Police, Firefighting, Emerge...    8.49
# 2                                          Thronefall    5.24
# 3   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...   23.99
# 4                                             UNDYING   13.99
# ..                                                ...     ...
# 81                         Bendy and the Dark Revival    5.99
# 82  STAR WARS™ - The Force Unleashed™ Ultimate Sit...    6.99
# 83                                           Thymesia   14.99
# 84                                    Last Train Home   26.39
# 85                                         Fallout 76    9.99
#
#     Porcentaje_Venta        Reviews_Recientes            Total_Reviews
# 0              -67.0  Overwhelmingly Positive  Overwhelmingly Positive
# 1              -66.0            Very Positive            Very Positive
# 2              -25.0  Overwhelmingly Positive  Overwhelmingly Positive
# 3              -40.0            Very Positive            Very Positive
# 4              -30.0          Mostly Positive          Mostly Positive
# ..               ...                      ...                      ...
# 81             -80.0            Very Positive            Very Positive
# 82             -65.0            Very Positive            Very Positive
# 83             -40.0            Very Positive            Very Positive
# 84             -34.0            Very Positive            Very Positive
# 85             -75.0          Mostly Positive          Mostly Positive
#
# [86 rows x 5 columns]

# %% [markdown]
# Aqui usamos media_ para sacar la media, mediana y moda del porcentaje de ventas de nuestro data set con esto dandonos los datos que necesitamos para la tabla.

# %%
media_PVenta = df_final_2['Porcentaje_Venta'].mean()
mediana_PVenta = df_final_2['Porcentaje_Venta'].median()
moda_PVenta = df_final_2['Porcentaje_Venta'].mode()[0]

# %% [markdown]
# usamos un pequeño diccionario para mostrar la media, mediana y la moda en la tabla, y usando las variables que realizamos en la parte de arriba

# %%
estadisticas = {
    'estadística': ['Media', 'Mediana', 'Moda'],
    'valor': [media_PVenta, mediana_PVenta, moda_PVenta]
}
df_final_2 = pd.DataFrame(estadisticas)

plt.figure(figsize=(10, 6))
plt.bar(df_final_2['estadística'], df_final_2['valor'], color=['purple', 'green', 'orange'])

plt.xlabel('Estadística')
plt.ylabel('Porcentaje de Venta')
plt.title('Media, Mediana y Moda del Porcentaje de Venta')
plt.show()

# %% [markdown]
# ### Grafica BoxPlot de precio y porcentaje de ventas.

# %% [markdown]
# Y aqui tenemos la tabla lista para interpretar de mejor manera!

# %%
# Crear el scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Precio', y='Porcentaje_Venta', data=df_final_2)

# Añadir etiquetas y título
plt.xlabel('Precio')
plt.ylabel('Porcentaje de Venta')
plt.title('Relación entre Precio y Porcentaje de Venta')
plt.show()

# %% [markdown]
# ## scatter plot

# %%
# Crear un scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_final_2['Precio'], y=df_final_2['Porcentaje_Venta'])
plt.title('Precio vs. Porcentaje Venta')
plt.xlabel('Precio ($)')
plt.ylabel('Porcentaje venta (%)')
plt.show()
